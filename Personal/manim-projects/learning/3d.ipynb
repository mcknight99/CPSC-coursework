# %% [markdown]
# https://slama.dev/manim/plotting-and-3d-scenes/

# %%
import manim as mn
from manim import *

config.media_width = "75%"
config.verbosity = "WARNING"

print(mn.__version__)
# Out:
# 0.20.1

# %%
# %%manim -qm Axes3DExample
#
# class Axes3DExample(ThreeDScene):
#     def construct(self):
#         axes = ThreeDAxes()
#
#         x_label = axes.get_x_axis_label(Tex("x"))
#         y_label = axes.get_y_axis_label(Tex("y")).shift(UP * 1.8)
#
#         # 3D variant of the Dot() object
#         dot = Dot3D()
#
#         # zoom out so we see the axes
#         self.set_camera_orientation(zoom=0.5)
#
#         self.play(FadeIn(axes), FadeIn(dot), FadeIn(x_label), FadeIn(y_label))
#
#         self.wait(0.5)
#
#         # animate the move of the camera to properly see the axes
#         self.move_camera(phi=75 * DEGREES, theta=30 * DEGREES, zoom=1, run_time=1.5)
#
#         # built-in updater which begins camera rotation
#         self.begin_ambient_camera_rotation(rate=0.15)
#
#         # one dot for each direction
#         upDot = dot.copy().set_color(RED)
#         rightDot = dot.copy().set_color(BLUE)
#         outDot = dot.copy().set_color(GREEN)
#
#         self.wait(1)
#
#         self.play(
#             upDot.animate.shift(UP),
#             rightDot.animate.shift(RIGHT),
#             outDot.animate.shift(OUT),
#         )
#
#         self.wait(2)
# Out:
# Manim Community v0.20.1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 get_ipython().run_cell_magic('manim', '-qm Axes3DExample', '\nclass Axes3DExample(ThreeDScene):\n    def construct(self): \n        axes = ThreeDAxes()\n\n        x_label = axes.get_x_axis_label(Tex("x"))\n        y_label = axes.get_y_axis_label(Tex("y")).shift(UP * 1.8)\n\n        # 3D variant of the Dot() object\n        dot = Dot3D()\n\n        # zoom out so we see the axes\n        self.set_camera_orientation(zoom=0.5)\n\n        self.play(FadeIn(axes), FadeIn(dot), FadeIn(x_label), FadeIn(y_label))\n\n        self.wait(0.5)\n\n        # animate the move of the camera to properly see the axes\n        self.move_camera(phi=75 * DEGREES, theta=30 * DEGREES, zoom=1, run_time=1.5)\n\n        # built-in updater which begins camera rotation\n        self.begin_ambient_camera_rotation(rate=0.15)\n\n        # one dot for each direction\n        upDot = dot.copy().set_color(RED)\n        rightDot = dot.copy().set_color(BLUE)\n        outDot = dot.copy().set_color(GREEN)\n\n        self.wait(1)\n\n        self.play(\n            upDot.animate.shift(UP),\n            rightDot.animate.shift(RIGHT),\n            outDot.animate.shift(OUT),\n        )\n\n        self.wait(2)\n')
#
# File ~\Documents\GitHub\CPSC-coursework\.venv\Lib\site-packages\manim\utils\ipython_magic.py:165, in ManimMagic.manim(self, line, cell, local_ns)
#     158 tmpfile = (
#     159     Path(config["media_dir"])
#     160     / "jupyter"
#     161     / f"{_generate_file_name()}{local_path.suffix}"
#     162 )
#     164 if local_path in self.rendered_files:
# --> 165     self.rendered_files[local_path].unlink()
#     166 self.rendered_files[local_path] = tmpfile
#     167 tmpfile.parent.mkdir(parents=True, exist_ok=True)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\Lib\pathlib\_local.py:746, in Path.unlink(self, missing_ok)
#     741 """
#     742 Remove this file or link.
#     743 If the path is a directory, use rmdir() instead.
#     744 """
#     745 try:
# --> 746     os.unlink(self)
#     747 except FileNotFoundError:
#     748     if not missing_ok:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'media\\jupyter\\Axes3DExample@2026-08-04@20-17-41.mp4'

# %%
# %%manim -qm Rotation3DExample
#
# class Rotation3DExample(ThreeDScene):
#     def construct(self):
#         cube = Cube(side_length=3, fill_opacity=0.8)
#
#         self.begin_ambient_camera_rotation(rate=0.3)
#
#         self.set_camera_orientation(phi=75 * DEGREES, theta=30 * DEGREES)
#
#         self.play(Write(cube), run_time=2)
#
#         self.wait(3)
#
#         self.play(Unwrite(cube), run_time=2)
# Out:
# Manim Community v0.20.1
# <video src="media\jupyter\Rotation3DExample@2026-08-04@19-32-05.mp4" controls autoplay loop style="max-width: 75%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Basic3DExample
#
# class Basic3DExample(ThreeDScene):
#     def construct(self):
#         cube = Cube(side_length=3, fill_opacity=0.5)
#
#         self.set_camera_orientation(phi=75 * DEGREES, theta=30 * DEGREES)
#
#         self.play(FadeIn(cube))
#
#         for axis in [RIGHT, UP, OUT]:
#             self.play(Rotate(cube, PI / 2, about_point=ORIGIN, axis=axis))
#
#         self.play(FadeOut(cube))
# Out:
# Manim Community v0.20.1
# <video src="media\jupyter\Basic3DExample@2026-08-04@19-32-38.mp4" controls autoplay loop style="max-width: 75%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm BooleanOperations3DExample
#
# config.verbosity = "CRITICAL"
#
# class BooleanOperations3DExample(ThreeDScene):
#     def construct(self):
#         cube = Cube(side_length=3, fill_opacity=0.5)
#         sphere = Sphere(radius=1.5, fill_opacity=0.5).shift(UP*0.75).shift(RIGHT*0.75).shift(OUT*0.75)
#
#         # march camera from 0 to 180 phi and 0 to 360 theta
#         self.set_camera_orientation(phi=0 * DEGREES, theta=0 * DEGREES)
#
#         # self.set_camera_orientation(phi=90 * DEGREES, theta=0 * DEGREES)
#
#         self.begin_ambient_camera_rotation(rate=0.15)
#
#
#         self.play(FadeIn(cube), FadeIn(sphere))
#
#         union = Union(cube, sphere, fill_opacity=0.5)
#         intersection = Intersection(cube, sphere, fill_opacity=0.5)
#         difference = Difference(cube, sphere, fill_opacity=0.5)
#         exclusion = Exclusion(cube, sphere, fill_opacity=0.5)
#
#
#         self.wait(1)
#
#
#         self.wait(1)
# Out:
# Manim Community v0.20.1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().run_cell_magic('manim', '-qm BooleanOperations3DExample', '\nconfig.verbosity = "CRITICAL"\n\nclass BooleanOperations3DExample(ThreeDScene):\n    def construct(self):\n        cube = Cube(side_length=3, fill_opacity=0.5)\n        sphere = Sphere(radius=1.5, fill_opacity=0.5).shift(UP*0.75).shift(RIGHT*0.75).shift(OUT*0.75)\n\n        # march camera from 0 to 180 phi and 0 to 360 theta\n        self.set_camera_orientation(phi=0 * DEGREES, theta=0 * DEGREES)\n\n        # self.set_camera_orientation(phi=90 * DEGREES, theta=0 * DEGREES)\n\n        self.begin_ambient_camera_rotation(rate=0.15)\n\n\n        self.play(FadeIn(cube), FadeIn(sphere))\n\n        union = Union(cube, sphere, fill_opacity=0.5)\n        intersection = Intersection(cube, sphere, fill_opacity=0.5)\n        difference = Difference(cube, sphere, fill_opacity=0.5)\n        exclusion = Exclusion(cube, sphere, fill_opacity=0.5)\n\n\n        self.wait(1)\n\n\n        self.wait(1)\n')
#
# File ~\Documents\GitHub\CPSC-coursework\.venv\Lib\site-packages\manim\utils\ipython_magic.py:165, in ManimMagic.manim(self, line, cell, local_ns)
#     158 tmpfile = (
#     159     Path(config["media_dir"])
#     160     / "jupyter"
#     161     / f"{_generate_file_name()}{local_path.suffix}"
#     162 )
#     164 if local_path in self.rendered_files:
# --> 165     self.rendered_files[local_path].unlink()
#     166 self.rendered_files[local_path] = tmpfile
#     167 tmpfile.parent.mkdir(parents=True, exist_ok=True)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\Lib\pathlib\_local.py:746, in Path.unlink(self, missing_ok)
#     741 """
#     742 Remove this file or link.
#     743 If the path is a directory, use rmdir() instead.
#     744 """
#     745 try:
# --> 746     os.unlink(self)
#     747 except FileNotFoundError:
#     748     if not missing_ok:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'media\\jupyter\\BooleanOperations3DExample@2026-08-04@20-18-31.mp4'
